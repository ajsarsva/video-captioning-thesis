# %% [markdown]
# <a href="https://colab.research.google.com/github/ajsarsva/video-captioning-thesis/blob/main/notebooks/colab_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

base = '/content/drive/MyDrive/thesis-data'

folders = [
    'videos',
    'frames',
    'captions',
    'results'
]

for folder in folders:
    path = os.path.join(base, folder)
    os.makedirs(path, exist_ok=True)
    print(f"Created: {path}")
# Out:
# Created: /content/drive/MyDrive/thesis-data/videos
# Created: /content/drive/MyDrive/thesis-data/frames
# Created: /content/drive/MyDrive/thesis-data/captions
# Created: /content/drive/MyDrive/thesis-data/results

# %%
for folder in folders:
    path = os.path.join(base, folder)
    print(f"{path} — exists: {os.path.exists(path)}")
# Out:
# /content/drive/MyDrive/thesis-data/videos — exists: True
# /content/drive/MyDrive/thesis-data/frames — exists: True
# /content/drive/MyDrive/thesis-data/captions — exists: True
# /content/drive/MyDrive/thesis-data/results — exists: True

# %%
# !git clone https://github.com/ajsarsva/video-captioning-thesis.git
# Out:
# Cloning into 'video-captioning-thesis'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 8 (delta 0), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), done.

# %%
import torch
print(torch.cuda.is_available())       # Should print True
print(torch.cuda.get_device_name(0))   # Should print something like Tesla T4
# Out:
# True
# Tesla T4

# %%
import shutil

# Copy notebook to your cloned repo's notebooks folder
shutil.copy(
    '/content/drive/MyDrive/thesis-data/setup.ipynb',   # if saved to drive
    '/content/video-captioning-thesis/notebooks/colab_setup.ipynb'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8052/1780297096.py in <cell line: 0>()
#       2
#       3 # Copy notebook to your cloned repo's notebooks folder
# ----> 4 shutil.copy(
#       5     '/content/drive/MyDrive/thesis-data/setup.ipynb',   # if saved to drive
#       6     '/content/video-captioning-thesis/notebooks/colab_setup.ipynb'
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
# ...

# %%
# !pip install transformers accelerate Pillow opencv-python-headless -q

import transformers
import cv2
from PIL import Image
print("All libraries loaded successfully!")
# Out:
# All libraries loaded successfully!
